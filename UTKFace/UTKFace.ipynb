# %% [markdown]
# ### 사전작업

# %%
# !ls
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /drive/MyDrive/
# Out:
# [Errno 2] No such file or directory: '/drive/MyDrive/'
# /content

# %%
# !ls /content/drive/MyDrive
# Out:
#  Classroom		  MiVOLO	'응시료_이찬영_2019098068_ICT 융합학부.pdf'
# 'Colab Notebooks'	  MultiMNIST	 이찬영_lcy1221@hanyang.ac.kr_ICT융합학부.png
#  data			  UTKFace	 이찬영_lcy1221@hanyang.ac.kr_병적증명서.pdf
#  dataset		  wandb		 이찬영_lcy1221@hanyang.ac.kr_성적증명서.pdf
# 'Git 수료증_이찬영.pdf'   yolov5	 이찬영_lcy1221@hanyang.ac.kr_재학증명서.jpg
#  KAIRI			  YOLOv5.ipynb	 주거비_이찬영_2019098068_ICT융합학부.pdf

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  Classroom		  MiVOLO	'응시료_이찬영_2019098068_ICT 융합학부.pdf'
# 'Colab Notebooks'	  MultiMNIST	 이찬영_lcy1221@hanyang.ac.kr_ICT융합학부.png
#  data			  UTKFace	 이찬영_lcy1221@hanyang.ac.kr_병적증명서.pdf
#  dataset		  wandb		 이찬영_lcy1221@hanyang.ac.kr_성적증명서.pdf
# 'Git 수료증_이찬영.pdf'   yolov5	 이찬영_lcy1221@hanyang.ac.kr_재학증명서.jpg
#  KAIRI			  YOLOv5.ipynb	 주거비_이찬영_2019098068_ICT융합학부.pdf

# %%
ls
# Out:
#  Classroom/               MiVOLO/       '응시료_이찬영_2019098068_ICT 융합학부.pdf'
# 'Colab Notebooks'/        MultiMNIST/   '이찬영_lcy1221@hanyang.ac.kr_ICT융합학부.png'
#  data/                    UTKFace/      '이찬영_lcy1221@hanyang.ac.kr_병적증명서.pdf'
#  dataset/                 wandb/        '이찬영_lcy1221@hanyang.ac.kr_성적증명서.pdf'
# 'Git 수료증_이찬영.pdf'   yolov5/       '이찬영_lcy1221@hanyang.ac.kr_재학증명서.jpg'
#  KAIRI/                   YOLOv5.ipynb   주거비_이찬영_2019098068_ICT융합학부.pdf

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images, self.labels = self.load_data()

    def load_data(self):
        images = []
        labels = []
        for filename in os.listdir(self.root_dir):
            if filename.endswith('.jpg'):
                img_path = os.path.join(self.root_dir, filename)
                images.append(img_path)

                # Extract labels from the filename
                parts = filename.split('_')
                try:
                    age, gender, race, _ = parts
                    age = int(age)
                    gender = int(gender)
                    race = int(race)
                    print(age, gender, race)
                except ValueError:
                    print(f"Unexpected format for filename: {filename}")


                # Combine extracted information into a label
                label = {'age': age, 'gender': gender, 'race': race}
                labels.append(label)

        return images, labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        # Load image
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# Set your data folder path
data_folder = '/content/drive/MyDrive/UTKFace/data/part1/'

# Set your desired image transformation
custom_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Create an instance of your custom dataset
custom_dataset = CustomDataset(root_dir=data_folder, transform=custom_transform)

# Create DataLoader
batch_size = 32
data_loader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 0
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 2
# 30 0 3
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 0 3
# 30 1 0
# 30 1 0
# 30 1 0
# 30 0 4
# 30 0 4
# 30 1 0
# 30 1 0
# 30 0 4
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 1
# 30 1 0
# 30 1 0
# 30 1 0
# 30 1 1
# 30 1 0
# 30 1 0
# 30 1 2
# 30 1 1
# 30 1 2
# 30 1 3
# 30 1 2
# 30 1 1
# 30 1 2
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 30 1 3
# 31 0 0
# 30 1 4
# 30 1 3
# 30 1 4
# 30 1 3
# 30 1 3
# 31 0 0
# 31 0 3
# 31 0 0
# 31 0 0
# 31 0 1
# 31 0 0
# 31 0 0
# 31 1 0
# 31 1 0
# 31 1 0
# 32 0 0
# 32 0 0
# 31 1 3
# 31 1 0
# 31 1 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 1
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 0
# 32 0 1
# 32 0 3
# 32 0 1
# 32 0 3
# 32 0 3
# 32 0 3
# 32 0 3
# 32 0 1
# 32 0 2
# 32 1 0
# 32 1 0
# 32 1 0
# 32 1 0
# 32 1 0
# 32 1 0
# 32 1 0
# 32 1 0
# 33 0 0
# 32 1 0
# 32 1 0
# 33 0 0
# 32 1 0
# 32 1 0
# 32 1 1
# 33 0 0
# 33 0 3
# 33 0 0
# 33 0 1
# 33 0 0
# 33 0 2
# 33 0 3
# 33 0 3
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 33 1 0
# 34 0 0
# 34 0 0
# 34 0 0
# 33 1 4
# 34 0 0
# 33 1 3
# 34 0 0
# 33 1 1
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 0 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 2
# 40 1 3
# 40 1 2
# 40 1 2
# 41 0 2
# 41 0 2
# 40 1 2
# 41 1 2
# 42 1 2
# 42 1 2
# 43 1 2
# 42 0 2
# 43 0 2
# 42 1 2
# 42 1 2
# 44 0 2
# 43 1 2
# 46 0 2
# 46 0 0
# 47 0 2
# 46 0 0
# 45 0 2
# 47 0 2
# 45 0 2
# 45 0 2
# 45 0 2
# 46 0 2
# 50 0 0
# 49 0 0
# 50 0 0
# 47 0 2
# 50 0 0
# 47 0 3
# 50 0 2
# 50 0 2
# 50 0 0
# 50 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 51 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 50 0 2
# 50 1 2
# 52 0 2
# 52 0 0
# 52 0 0
# 52 0 2
# 52 0 2
# 52 0 0
# 53 0 1
# 52 1 2
# 54 0 2
# 54 0 0
# 53 0 2
# 54 0 0
# 53 0 2
# 54 0 2
# 54 0 2
# 55 0 0
# 55 0 2
# 55 1 2
# 54 0 2
# 54 1 2
# 54 1 2
# 54 1 2
# 58 0 2
# 58 0 2
# 58 0 2
# 56 0 2
# 57 1 2
# 58 0 2
# 56 0 0
# 58 0 2
# 60 0 2
# 58 0 2
# 60 0 2
# 60 0 0
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 60 0 2
# 61 0 2
# 61 0 2
# 62 1 0
# 60 1 2
# 62 0 2
# 61 0 2
# 60 0 2
# 61 0 2
# 64 0 2
# 62 1 2
# 67 0 2
# 68 0 2
# 64 0 2
# 64 0 2
# 67 0 3
# 68 0 2
# 70 0 2
# 68 0 2
# 69 0 0
# 70 0 2
# 72 0 0
# 68 0 2
# 1 1 0
# 1 1 2
# 79 0 2
# 1 1 0
# 1 1 4
# 1 0 2
# 1 1 4
# 3 1 1
# 4 1 0
# 4 1 1
# 5 1 1
# 2 0 0
# 2 1 0
# 2 1 4
# 6 1 0
# 6 1 1
# 6 0 0
# 6 1 1
# 8 1 4
# 6 1 4
# 14 0 4
# 12 1 4
# 12 1 2
# 10 1 4
# 14 0 4
# 12 1 0
# 13 1 4
# 18 1 4
# 16 1 0
# 17 0 0
# 14 0 4
# 17 1 4
# 18 1 0
# 18 0 0
# 20 0 4
# 20 0 2
# 20 0 4
# 19 0 4
# 20 0 4
# 20 0 4
# 20 0 4
# 20 0 4
# 20 1 0
# 20 1 0
# 20 1 0
# 20 1 0
# 20 1 4
# 20 1 0
# 21 0 0
# 20 1 4
# 21 0 2
# 21 0 0
# 20 1 4
# 21 1 4
# 21 1 1
# 21 1 3
# 21 1 1
# 21 1 0
# 21 1 0
# 21 1 0
# 22 1 0
# 22 0 0
# 21 1 4
# 22 0 0
# 22 0 4
# 21 1 4
# 22 0 0
# 23 0 0
# 22 1 0
# 22 1 4
# 23 0 0
# 22 1 4
# 22 1 4
# 22 1 4
# 23 0 4
# 23 0 1
# 23 0 0
# 23 0 1
# 23 0 0
# 23 0 1
# 23 0 4
# 23 0 4
# 23 0 4
# 23 0 4
# 23 0 4
# 23 0 4
# 23 1 4
# 23 1 4
# 23 1 1
# 23 1 4
# 23 1 0
# 23 1 0
# 23 1 4
# 23 1 4
# 23 1 4
# 23 1 4
# 23 1 4
# 23 1 4
# 23 1 4
# 24 0 0
# 24 0 0
# 24 0 0
# 24 0 1
# 24 0 0
# 24 0 1
# 23 1 4
# 24 0 1
# 24 0 4
# 24 0 1
# 24 0 4
# 24 0 1
# 24 0 1
# 24 0 1
# 24 0 4
# 24 0 4
# 24 1 0
# 24 0 4
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 0
# 24 1 2
# 24 1 0
# 24 1 0
# 24 1 2
# 24 1 1
# 24 1 1
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 24 1 4
# 25 0 0
# 25 0 0
# 25 0 0
# 25 0 0
# 25 0 0
# 25 0 1
# 25 0 0
# 25 0 1
# 25 0 0
# 25 0 0
# 25 0 1
# 25 0 0
# 25 0 2
# 25 0 4
# 25 0 4
# 25 0 4
# 25 0 4
# 25 0 4
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 0
# 25 0 4
# 25 1 0
# 25 1 0
# 25 1 1
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 0
# 25 1 4
# 25 1 4
# 26 0 0
# 25 1 4
# 25 1 4
# 25 1 4
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 0
# 26 0 1
# 26 0 0
# 26 0 0
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 1
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 2
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 0 4
# 26 1 0
# 26 1 0
# 26 1 0
# 26 0 4
# 26 1 0
# 26 0 4
# 26 0 4
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 4
# 26 1 4
# 26 1 2
# 26 1 4
# 26 1 4
# 26 1 2
# 26 1 1
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 26 1 4
# 27 0 0
# 26 1 4
# 27 0 0
# 27 0 0
# 26 1 4
# 27 0 0
# 26 1 4
# 27 0 1
# 27 0 4
# 27 0 4
# 27 0 0
# 27 0 0
# 27 0 4
# 27 1 0
# 27 1 0
# 27 1 1
# 27 1 0
# 27 1 0
# 27 0 4
# 27 1 0
# 28 0 0
# 28 0 0
# 28 0 0
# 28 0 0
# 28 0 0
# 28 0 0
# 27 1 4
# 28 0 0
# 28 0 0
# 28 0 1
# 28 0 0
# 28 0 1
# 28 0 0
# 28 0 0
# 28 0 1
# 28 0 4
# 28 0 4
# 28 0 4
# 28 0 4
# 28 0 4
# 28 0 1
# 28 1 0
# 28 0 4
# 28 1 0
# 28 1 0
# 28 0 4
# 28 1 0
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 0
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 28 1 4
# 29 0 0
# 29 0 1
# 29 0 0
# 29 0 0
# 29 0 0
# 29 0 1
# 29 0 1
# 29 0 4
# 29 1 0
# 29 0 4
# 29 1 1
# 29 1 0
# 29 0 4
# 29 1 4
# 29 1 4
# 29 1 4
# 30 0 1
# 30 0 0
# 30 0 0
# 30 0 2
# 30 0 1
# 30 0 4
# 30 0 4
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 1
# 30 0 4
# 30 0 4
# 30 0 4
# 30 0 4
# 30 0 4
# 30 1 0
# 30 1 1
# 30 1 0
# 30 1 4
# 30 0 4
# 30 1 0
# 30 1 0
# 30 1 4
# 30 1 4
# 30 1 4
# 30 1 4
# 30 1 4
# 30 1 4
# 30 1 4
# 31 0 0
# 31 0 0
# 30 1 4
# 30 1 4
# 31 0 0
# 30 1 4
# 31 1 4
# 31 0 1
# 31 1 4
# 31 1 4
# 31 1 4
# 31 1 4
# 31 1 4
# 32 0 4
# 32 0 4
# 32 0 0
# 32 1 0
# 32 1 0
# 32 0 4
# 32 1 4
# 32 1 4
# 32 1 0
# 32 1 1
# 32 1 4
# 32 1 1
# 32 1 4
# 33 0 4
# 33 0 4
# 33 1 4
# 32 1 4
# 33 0 4
# 33 0 1
# 34 0 0
# 34 0 0
# 34 0 1
# 34 0 0
# 33 1 4
# 34 0 1
# 34 0 4
# 35 0 0
# 35 0 0
# 35 0 1
# 35 0 0
# 35 0 0
# 35 0 0
# 35 0 0
# 35 0 4
# 35 0 4
# 35 0 4
# 35 0 4
# 35 0 4
# 35 0 4
# 35 0 4
# 35 1 0
# 35 1 0
# 35 1 0
# 35 1 0
# 35 1 0
# 35 1 0
# 35 1 0
# 35 1 1
# 35 1 1
# 35 1 1
# 35 1 1
# 35 1 1
# 35 1 0
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 35 1 4
# 36 0 0
# 36 0 0
# 35 1 4
# 36 0 0
# 37 1 0
# 36 0 4
# 36 0 4
# 36 0 4
# 36 0 1
# 36 1 4
# 36 0 1
# 38 1 1
# 38 1 4
# 37 1 4
# 37 1 4
# 38 1 4
# 38 1 1
# 39 1 0
# 38 1 4
# 38 1 4
# 39 1 4
# 38 1 4
# 40 0 0
# 38 1 4
# 40 0 4
# 40 0 4
# 40 0 0
# 40 0 0
# 40 0 0
# 40 0 0
# 40 0 4
# 40 1 0
# 40 1 4
# 40 1 0
# 41 1 4
# 42 0 0
# 42 1 0
# 40 0 4
# 41 1 1
# 43 0 4
# 42 1 0
# 42 1 4
# 43 0 0
# 43 1 4
# 43 1 4
# 43 1 4
# 45 0 0
# 45 0 0
# 45 0 0
# 45 0 0
# 44 0 4
# 45 0 1
# 45 0 4
# 45 0 0
# 45 0 4
# 45 0 0
# 45 0 4
# 45 0 1
# 45 0 4
# 45 0 4
# 45 0 4
# 45 0 4
# 45 0 4
# 45 0 4
# 50 0 0
# 45 1 0
# 45 1 4
# 48 0 4
# 45 1 0
# 50 0 0
# 47 0 0
# 50 1 0
# 50 0 4
# 50 0 1
# 50 0 4
# 50 1 4
# 50 0 4
# 50 0 4
# 50 1 4
# 53 1 0
# 53 1 4
# 54 0 0
# 53 0 4
# 53 1 4
# 53 1 4
# 54 0 4
# 54 0 4
# 54 1 0
# 54 0 0
# 54 0 0
# 54 1 0
# 54 0 4
# 55 0 1
# 54 1 0
# 55 0 0
# 54 1 1
# 55 0 4
# 55 0 0
# 55 0 0
# 55 0 4
# 55 1 1
# 55 0 4
# 58 0 1
# 55 1 4
# 58 0 0
# 55 1 0
# 58 0 4
# 61 0 0
# 61 1 0
# 58 1 0
# 60 0 0
# 58 0 4
# 58 1 0
# 63 1 0
# 65 0 0
# 65 1 4
# 75 0 0
# 67 0 0
# 65 0 0
# 73 0 0
# 5 1 0
# 5 0 3
# 1 0 0
# 5 0 0
# 1 0 0
# 80 0 0
# 5 1 0
# 2 1 1
# 6 0 0
# 8 0 4
# 23 0 0
# 23 0 0
# 23 0 0
# 23 0 0
# 23 0 3
# 23 0 2
# 23 1 0
# 23 1 0
# 23 0 4
# 23 0 1
# 23 1 0
# 23 1 0
# 23 0 3
# 23 1 0
# 23 0 3
# 23 1 0
# 25 1 2
# 25 1 2
# 25 1 2
# 25 1 2
# 23 0 0
# 26 0 0
# 26 0 2
# 25 1 2
# 25 1 2
# 24 0 0
# 26 1 0
# 25 1 2
# 26 0 2
# 26 0 0
# 26 0 2
# 58 0 0
# 56 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 0 2
# 54 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 54 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 1 0
# 60 1 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 0 2
# 63 0 0
# 26 0 2
# 26 0 2
# 26 0 0
# 40 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 63 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 57 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 1 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 0 2
# 26 0 2
# 38 0 0
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 2
# 26 0 0
# 26 0 2
# 26 0 2
# 26 1 0
# 26 1 0
# 26 0 2
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 0 2
# 26 0 2
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 0
# 26 1 1
# 26 1 0
# 26 1 1
# 26 1 0
# 26 1 0
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 1
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 1
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 3
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 2
# 26 1 3
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 26 1 3
# 26 1 4
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 1 0
# 27 1 0
# 27 0 2
# 27 0 2
# 27 0 2
# 27 0 2
# 27 1 0
# 27 1 2
# 27 1 2
# 27 0 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 2
# 27 1 3
# 27 1 2
# 27 1 2
# 27 1 2
# 28 0 1
# 28 0 0
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 0 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 0
# 28 1 0
# 28 1 2
# 28 1 2
# 28 1 0
# 28 1 2
# 28 1 0
# 28 0 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 2
# 28 1 3
# 28 1 2
# 28 1 2
# 28 1 2
# 29 0 2
# 29 0 2
# 29 0 0
# 29 0 2
# 29 0 2
# 29 0 0
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 1 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 0 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 29 1 2
# 30 0 0
# 30 0 2
# 30 0 0
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 0 2
# 30 1 2
# 30 1 0
# 30 1 0
# 30 1 2
# 30 1 2
# 30 0 2
# 30 1 2
# 30 1 2
# 30 0 2
# 30 0 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 2
# 30 1 3
# 31 0 0
# 31 0 1
# 30 1 2
# 31 0 1
# 31 0 0
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 0 2
# 31 1 2
# 31 1 2
# 31 0 2
# 31 0 2
# 31 1 2
# 31 0 4
# 31 1 2
# 31 0 2
# 31 1 2
# 32 0 2
# 31 1 2
# 32 0 0
# 32 0 0
# 32 0 2
# 32 0 2
# 32 0 0
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 0 2
# 32 1 0
# 32 0 2
# 32 0 2
# 32 0 3
# 32 0 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
# 32 1 2
#
# 46 1 1
# 51 0 2
# 50 1 1
# 52 1 2
# 56 1 1
# 54 1 1
# 56 1 0
# 56 0 2
# 55 0 2
# 58 0 2
# 57 0 0
# 58 0 2
# 58 0 3
# 58 0 3
# 60 1 1
# 59 1 1
# 58 0 3
# 60 1 1
# 60 0 2
# 61 0 2
# 61 0 2
# 61 0 2
# 62 0 2
# 62 0 3
# 62 0 2
# 65 0 0
# 65 0 2
# 68 1 1
# 67 0 0
# 65 0 2
# 71 0 2
# 72 0 0
# 72 0 2
# 72 0 2
# 72 0 2
# 75 0 2
# 72 0 2
# 75 0 2
# 75 0 2
# 75 0 2
# 75 0 2
# 75 0 2
# 75 0 3
# 76 1 0
# 76 0 2
# 75 1 1
# 76 0 2
# 76 0 2
# 78 0 2
# 76 1 1
# 76 1 2
# 78 0 2
# 78 0 2
# 78 1 2
# 77 0 2
# 4 1 1
# 80 0 2
# 86 0 2
# 80 0 2
# 85 1 2
# 82 0 2
# 12 1 1
# 24 1 1
# 25 1 1
# 25 1 1
# 22 1 1
# 26 1 0
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 26 1 1
# 27 0 0
# 27 1 1
# 27 1 1
# 27 1 3
# 27 1 1
# 27 1 1
# 28 0 2
# 27 1 1
# 27 1 1
# 28 1 1
# 28 1 1
# 28 1 1
# 28 1 1
# 28 1 1
# 28 1 1
# 28 1 1
# 29 1 1
# 29 0 1
# 29 1 1
# 30 1 1
# 30 1 1
# 29 1 1
# 30 0 1
# 30 1 1
# 30 1 1
# 30 1 1
# 30 1 1
# 30 1 1
# 30 1 1
# 32 1 0
# 32 1 1
# 31 1 1
# 32 1 1
# 31 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 34 1 1
# 34 0 1
# 32 1 1
# 32 1 1
# 34 1 1
# 34 0 1
# 34 0 1
# 35 0 2
# 35 1 1
# 35 1 1
# 35 1 1
# 35 1 1
# 36 1 1
# 35 1 1
# 36 0 1
# 35 1 1
# 35 1 1
# 35 1 1
# 36 1 1
# 36 1 1
# 37 1 1
# 38 1 1
# 36 1 1
# 37 1 1
# 36 1 1
# 37 1 1
# 39 1 1
# 39 0 0
# 42 0 2
# 42 0 0
# 42 0 2
# 40 1 1
# 43 0 0
# 42 0 2
# 43 0 3
# 43 0 0
# 42 0 3
# 43 0 2
# 42 1 1
# 45 0 2
# 45 1 1
# 45 1 1
# 45 0 3
# 45 0 2
# 46 0 2
# 50 0 2
# 49 0 0
# 47 0 2
# 46 1 1
# 46 1 1
# 53 0 0
# 50 1 1
# 51 1 1
# 52 0 2
# 51 1 1
# 52 0 2
# 50 0 2
# 53 0 2
# 53 1 1
# 53 0 2
# 53 0 3
# 54 0 2
# 55 0 2
# 55 0 0
# 54 0 2
# 54 1 1
# 56 0 2
# 55 0 2
# 55 0 2
# 55 1 1
# 55 1 1
# 56 0 1
# 55 1 1
# 58 1 1
# 56 0 2
# 58 0 2
# 58 1 1
# 58 1 1
# 56 0 2
# 61 0 2
# 60 0 2
# 60 0 0
# 60 0 2
# 61 0 2
# 62 0 0
# 61 0 2
# 62 0 1
# 62 0 2
# 61 0 2
# 61 0 2
# 62 0 2
# 62 0 2
# 63 0 2
1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 1
# 32 1 2
# 33 1 0
# 32 1 4
# 32 1 1
# 33 1 0
# 33 0

# %%
# %cd /content/drive/MyDrive/UTKFace/

# %%
# !ls

# %%
# !python main.py

# %%
import os
from torchvision import datasets, transforms
import pandas as pd
import torch
import argparse
import cv2
torch.manual_seed(1004)

import torch.nn as nn
from torch.utils.data import DataLoader

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(DEVICE)

# Specify the root directory
root_dir = '/content/drive/MyDrive/UTKFace/data/part3/'

# Lists to store data
images = []
ages = []
genders = []
races = []

# Iterate through files in the root directory
for filename in os.listdir(root_dir):
    if filename.endswith('.jpg'):
        # Extract labels from the filename
        parts = filename.split('_')
        try:
            img_path = os.path.join(root_dir, filename)
            # img를 pd 데이터 프레임으로 변환
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            age, gender, race, _ = parts
            age = int(age)
            gender = int(gender)
            race = int(race)
            # Append labels to the lists
            ages.append(age)
            genders.append(gender)
            races.append(race)

        except ValueError:
            print(f"Unexpected format for filename: {filename}")
            continue

# Create a DataFrame from the lists
data = {'Image': images, 'Age': ages, 'Gender': genders, 'Race': races}
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Save the DataFrame to a CSV file
# df.to_csv('image_data.csv', index=False)

# %%
dir = '/content/drive/MyDrive/UTKFace/data/part1/'
img = cv2.imread(dir + '61_3_20170109150557335.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (224, 224))

# %%
# %cd /content/drive/MyDrive/UTKFace/

# %%
# !tar -xzvf part3.tar.gz

# %%
# !ls

# %%
# !python main.py

# %%
# %cd data

# %%
# !rm -rf part3

# %%
# !ls

# %%
# !mv part3.tar.gz ..

# %%
# %cd ..

# %%
# !tar -xzvf part1.tar.gz

# %%
import os
from torchvision import datasets, transforms
import pandas as pd
import torch
import argparse
import cv2
torch.manual_seed(1004)

import torch.nn as nn
from torch.utils.data import DataLoader

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(DEVICE)

# Specify the root directory
root_dir = '/content/drive/MyDrive/UTKFace/data/part1/'

# Lists to store data
images = []
ages = []
genders = []
races = []

# Iterate through files in the root directory
for filename in os.listdir(root_dir):
    if filename.endswith('.jpg'):
        # Extract labels from the filename
        parts = filename.split('_')
        try:
            img_path = os.path.join(root_dir, filename)
            # img를 pd 데이터 프레임으로 변환
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (224, 224))
            images.append(img)
            age, gender, race, _ = parts
            age = int(age)
            gender = int(gender)
            race = int(race)
            # Append labels to the lists
            ages.append(age)
            genders.append(gender)
            races.append(race)

        except ValueError:
            print(f"Unexpected format for filename: {filename}")
            continue

# Create a DataFrame from the lists
data = {'Image': images, 'Age': ages, 'Gender': genders, 'Race': races}
df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Save the DataFrame to a CSV file
# df.to_csv('image_data.csv', index=False)

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part1/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.8 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.2, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        if split == 'train':
            self.images = train_data
        elif split == 'val':
            self.images = val_data
        elif split == 'test':
            self.images = test_data

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []
        # Read images
        img_path = os.path.join(self.root, self.images[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[idx].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels


if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(DEVICE)

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models

# Define a custom neural network for regression
class RegressionNN(nn.Module):
    def __init__(self):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet18(pretrained=True)
        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 1)

    def forward(self, x):
        return self.resnet(x)

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part1/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.8 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.2, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        if split == 'train':
            self.images = train_data
        elif split == 'val':
            self.images = val_data
        elif split == 'test':
            self.images = test_data

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []
        # Read images
        img_path = os.path.join(self.root, self.images[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[idx].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

# Instantiate the regression model
regression_model = RegressionNN().to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.001)

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Training loop for regression
num_epochs = 10  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

# Evaluation loop for regression
regression_model.eval()
total_mse = 0.0

with torch.no_grad():
    for X, y in test_loader:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Forward pass
        predictions = regression_model(X)

        # Compute Mean Squared Error
        mse = age_loss(predictions, age_labels)
        total_mse += mse.item()

# Calculate the average Mean Squared Error on the test set
average_mse = total_mse / len(test_loader)
print(f"Average Mean Squared Error on the test set: {average_mse}")

# %% [markdown]
# ## UTKFace
#
# resnet50
#
# epoch = 50
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.001
#
# batch size : 32
#
# 최종 MAE = 13.71045794607127

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part1/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []
        # Read images
        img_path = os.path.join(self.root, self.images[idx])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[idx].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

# Define a custom neural network for regression
class RegressionNN(nn.Module):
    def __init__(self):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet50(pretrained=True)
        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 1)

    def forward(self, x):
        return self.resnet(x)

# Instantiate the regression model
regression_model = RegressionNN().to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mse = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            age_acc += (predictions.round() == age_labels).sum().item()

            # Compute Mean Squared Error
            mse = age_loss(predictions, age_labels)
            total_mse += mse.item()
            average_mse = total_mse / len(test_loader)

    age_acc = age_acc / len(test_loader)
    print(f"Age accuracy: {age_acc*100}%")

    return math.sqrt(total_mse), math.sqrt(average_mse)

# Training loop for regression
num_epochs = 50  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Squared Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Squared Error on the test set: {average_mse}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# torch.Size([32, 3, 224, 224])
# torch.Size([32, 3])
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 132MB/s]
# Epoch [1/50]: 100%|██████████| 528/528 [13:29<00:00,  1.53s/it, loss=241]
# Age accuracy: 121.23893805309736%
# Validation - Epoch [1/50], Average Mean Squared Error: 15.18522634748193
# Epoch [2/50]: 100%|██████████| 528/528 [06:48<00:00,  1.29it/s, loss=416]
# Age accuracy: 71.68141592920354%
# Validation - Epoch [2/50], Average Mean Squared Error: 20.477157984990665
# Epoch [3/50]: 100%|██████████| 528/528 [06:49<00:00,  1.29it/s, loss=385]
# Age accuracy: 67.2566371681416%
# Validation - Epoch [3/50], Average Mean Squared Error: 20.011994581512987
# Epoch [4/50]: 100%|██████████| 528/528 [06:49<00:00,  1.29it/s, loss=374]
# Age accuracy: 97.34513274336283%
# Validation - Epoch [4/50], Average Mean Squared Error: 20.195117256763208
# Epoch [5/50]: 100%|██████████| 528/528 [06:48<00:00,  1.29it/s, loss=362]
# Age accuracy: 67.2566371681416%
# Validation - Epoch [5/50], Average Mean Squared Error: 19.489685827868623
# Epoch [6/50]: 100%|██████████| 528/528 [06:49<00:00,  1.29it/s, loss=340]
# Age accuracy: 64.60176991150442%
# Validation - Epoch [6/50], Average Mean Squared Error: 19.277416648596596
# Epoch [7/50]: 100%|██████████| 528/528 [06:48<00:00,  1.29it/s, loss=323]
# Age accuracy: 58.4070796460177%
# Validation - Epoch [7/50], Average Mean Squared Error: 18.28295636010784
# Epoch [8/50]: 100%|██████████| 528/528 [06:47<00:00,  1.29it/s, loss=302]
# Age accuracy: 93.80530973451327%
# Validation - Epoch [8/50], Average Mean Squared Error: 18.240689264169724
# Age accuracy: 153.09734513274336%
# Validation - Epoch [24/50], Average Mean Squared Error: 13.037041062379028
# Epoch [25/50]: 100%|██████████| 528/528 [06:48<00:00,  1.29it/s, loss=108]
# Age accuracy: 137.16814159292034%
# Validation - Epoch [25/50], Average Mean Squared Error: 13.009833892714468
# Epoch [26/50]: 100%|██████████| 528/528 [06:46<00:00,  1.30it/s, loss=98.6]
# Age accuracy: 115.929203539823%
# Validation - Epoch [26/50], Average Mean Squared Error: 13.630443870780894
# Epoch [27/50]: 100%|██████████| 528/528 [06:46<00:00,  1.30it/s, loss=102]
# Age accuracy: 167.2566371681416%
# Validation - Epoch [27/50], Average Mean Squared Error: 13.249533008875384
# Epoch [28/50]: 100%|██████████| 528/528 [06:49<00:00,  1.29it/s, loss=86.3]
# Age accuracy: 132.7433628318584%
# Validation - Epoch [28/50], Average Mean Squared Error: 13.731654091479204
# Epoch [29/50]: 100%|██████████| 528/528 [06:48<00:00,  1.29it/s, loss=81.9]
# Age accuracy: 147.78761061946904%
# Validation - Epoch [29/50], Average Mean Squared Error: 13.601526625863507
# Epoch [30/50]:  94%|█████████▍| 496/528 [06:21<00:28,  1.11it/s, loss=72]

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break


class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet152(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout to the fully connected layer
        self.resnet.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.resnet.fc.in_features, 1)
        )

    def forward(self, x):
        return self.resnet(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 20  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## UTKFace
#
# resnet50
#
# epoch = 20
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE = 7.877353282684975

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break


class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet50(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout to the fully connected layer
        self.resnet.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.resnet.fc.in_features, 1)
        )

    def forward(self, x):
        return self.resnet(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    age_acc = age_acc / len(test_loader)
    print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 20  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## UTKFace
#
# resnet101
#
# epoch = 40
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.001
#
# batch size : 64
#
# 최종 MAE = 14.698365982542647

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break


class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet101(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout to the fully connected layer
        self.resnet.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.resnet.fc.in_features, 1)
        )

    def forward(self, x):
        return self.resnet(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 40  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# 이미지 증강 적용
# Dropout : 0.4
# resnet152

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random
import matplotlib.pyplot as plt

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # 데이터 정보를 기록할 리스트
        self.data_info = []

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)

        # 데이터 정보 추가
        data_info = {
            "File": self.images[selected_index],
            "Age": age,
            "Gender": gender,
            "Race": race
        }
        self.data_info.append(data_info)

        # 출력으로 데이터 정보 추가
        print(f"File: {self.images[selected_index]}, Age: {age}, Gender: {gender}, Race: {race}")
        return images, labels


image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
val_loader = DataLoader(val_set, batch_size=16, shuffle=False)
test_loader = DataLoader(test_set, batch_size=16, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained ResNet18 as a feature extractor
        self.resnet = models.resnet152(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout to the fully connected layer
        self.resnet.fc = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(self.resnet.fc.in_features, 1)
        )

    def forward(self, x):
        return self.resnet(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.4).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 40  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = age_loss(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## WANDB 설치

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.16.3-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.40.5-py2.py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 13.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.42 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.40.5 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.3

# %%
# !wandb login --relogin
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## UTKFace
#
# vgg16
#
# epoch = 100
#
# train : valid : test = 0.7 : 0.15 : 0.1
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE = 7.3653652312907765
#
# (new_cropped_faces) 폴더에서 실행

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained VGG16 as a feature extractor
        self.vgg = models.vgg16(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout and batch normalization to the fully connected layer
        in_features = self.vgg.classifier[6].in_features
        self.vgg.classifier[6] = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, 256),  # You can adjust the number of neurons in the new layer
            nn.BatchNorm1d(256),           # Batch normalization
            nn.ReLU(inplace=True),         # Activation function
            nn.Dropout(dropout_rate),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        return self.vgg(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 100  # You can adjust the number of epochs
for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))

    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## UTKFace
#
# vgg16
#
# epoch = 48
#
# train : valid : test = 0.8 : 0.1 : 0.1
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE = 7.076507242102372
#
# (new_cropped_faces 이후 얼굴 걸러내는 작업 한 번 더 진행한 후 실행)

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

import wandb
wandb.init(project='UTKFace regression')

wandb.run.name = 'RegressionNN'
wandb.run.save()

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part2/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.2, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained VGG16 as a feature extractor
        self.vgg = models.vgg16(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout and batch normalization to the fully connected layer
        in_features = self.vgg.classifier[6].in_features
        self.vgg.classifier[6] = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, 256),  # You can adjust the number of neurons in the new layer
            nn.BatchNorm1d(256),           # Batch normalization
            nn.ReLU(inplace=True),         # Activation function
            nn.Dropout(dropout_rate),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        return self.vgg(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 100  # You can adjust the number of epochs

args = {
    "learning_rate": 0.0001,
    "batch_size": 32,
    "epochs" : num_epochs
}
wandb.config.update(args)

for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))



    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")

    wandb.log({"Train loss" : total_loss / len(train_loader),
               "Validation loss" : validation_average_mse})


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## 데이터셋 사전 작업
#
# 얼굴만 잘라서 다른 폴더에 별도로 보관하는 코드

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.transforms import functional as F
from google.colab.patches import cv2_imshow

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

root='/content/drive/MyDrive/UTKFace/data/part1/'

images = []
for filename in os.listdir(root):
    if filename.endswith('.jpg'):
        images.append(filename)

# Load the pre-trained Haar Cascade face detector
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Function to detect faces in an image using Haar Cascade
def detect_faces_haar(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

    # Convert the (x, y, w, h) values to the format expected by the code
    boxes = [[x, y, x+w, y+h] for (x, y, w, h) in faces]

    return boxes

new_output_dir = '/content/drive/MyDrive/UTKFace/data/new_cropped_faces/'
os.makedirs(new_output_dir, exist_ok=True)

for i in range(len(images)):
    img_path = os.path.join(root, images[i])
    boxes = detect_faces_haar(img_path)
    # Crop the image to the detected face
    if len(boxes) > 0:
        img = cv2.imread(img_path)

        # Assuming there is only one face, process the first detected face
        box = boxes[0]

        # Display the image with bounding box
        cv2.rectangle(img, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)

        # Crop and display the detected face
        face = img[box[1]:box[3], box[0]:box[2]]
        # cv2_imshow(face)

        new_output_path = os.path.join(new_output_dir, images[i])  # Keep the same filename
        cv2.imwrite(new_output_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))

# %%
# !ls -l | grep ^- | wc -l

# %%
# %cd /content/drive/MyDrive/UTKFace/data/

# %%
# %cd new_cropped_faces

# %%
# %cd new_cropped_faces/

# %%
# !cp new_cropped_faces/ -r /content/drive/MyDrive/UTKFace/data/part2/

# %%
import cv2
import dlib
import os

# 얼굴 검출기 초기화
detector = dlib.get_frontal_face_detector()

# 대상 폴더 경로 설정
folder_path = "/content/drive/MyDrive/UTKFace/data/part2/new_cropped_faces"

# 폴더 내 파일들에 대한 루프
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    # 이미지 파일인 경우에만 처리
    if os.path.isfile(file_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # 이미지 읽기
        image = cv2.imread(file_path)

        # 그레이 스케일로 변환
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # 얼굴 검출
        faces = detector(gray)

        # 얼굴이 없으면 파일 삭제
        if len(faces) == 0:
            print(f"Deleting {filename} as no face is detected.")
            os.remove(file_path)
        else:
            print(f"Keeping {filename} with detected face.")

print("Process completed.")

# %% [markdown]
# ## UTKFace
#
# vgg16
#
# epoch = 50
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE = 8.0661
#
# (얼굴 crop 하지 않은 폴더에서 수행)
#
# ![스크린샷 2024-01-27 141520.png](data:image/png;base64,...)

# %% [markdown]
# ## UTKFace
#
# vgg19
#
# epoch = 50
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE = 8.617644584880155
#
# (new_cropped_faces 이후 얼굴 걸러내는 작업 한 번 더 진행한 후 실행)
#
# ![image.png](data:image/png;base64,...)

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

import wandb
wandb.init(project='UTKFace regression')

wandb.run.name = 'vgg19_with_crop2'
wandb.run.save()

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part2/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained VGG16 as a feature extractor
        self.vgg = models.vgg19(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout and batch normalization to the fully connected layer
        in_features = self.vgg.classifier[6].in_features
        self.vgg.classifier[6] = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, 256),  # You can adjust the number of neurons in the new layer
            nn.BatchNorm1d(256),           # Batch normalization
            nn.ReLU(inplace=True),         # Activation function
            nn.Dropout(dropout_rate),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        return self.vgg(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 50  # You can adjust the number of epochs

args = {
    "learning_rate": 0.0001,
    "batch_size": 32,
    "epochs" : num_epochs
}
wandb.config.update(args)

for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))



    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")

    wandb.log({"Train loss" : total_loss / len(train_loader),
               "Validation loss" : validation_average_mse})


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## vgg16
#
# epoch = 200
#
# train : valid : test = 0.7 : 0.15 : 0.15
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE =
#
# (new_cropped_faces 이후 얼굴 걸러내는 작업 한 번 더 진행한 후 실행)

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

import wandb
wandb.init(project='UTKFace regression')

wandb.run.name = 'vgg16_with_crop_x2'
wandb.run.save()

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part2/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.3, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained VGG16 as a feature extractor
        self.vgg = models.vgg16(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout and batch normalization to the fully connected layer
        in_features = self.vgg.classifier[6].in_features
        self.vgg.classifier[6] = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, 256),  # You can adjust the number of neurons in the new layer
            nn.BatchNorm1d(256),           # Batch normalization
            nn.ReLU(inplace=True),         # Activation function
            nn.Dropout(dropout_rate),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        return self.vgg(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 200  # You can adjust the number of epochs

args = {
    "learning_rate": 0.0001,
    "batch_size": 32,
    "epochs" : num_epochs
}
wandb.config.update(args)

for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))



    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")

    wandb.log({"Train loss" : total_loss / len(train_loader),
               "Validation loss" : validation_average_mse})


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %% [markdown]
# ## UTKFace
#
# epoch = 200
#
# train : valid : test = 0.8 : 0.1 : 0.1
#
# learning rate : 0.0001
#
# batch size : 32
#
# 최종 MAE =
#
# (new_cropped_faces 이후 얼굴 걸러내는 작업 한 번 더 진행한 후 실행)

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

import wandb
wandb.init(project='UTKFace regression')

wandb.run.name = 'vgg16_with_crop_x2'
wandb.run.save()

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='/content/drive/MyDrive/UTKFace/data/part2/new_cropped_faces/', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.2, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

image_transform = transforms.Compose([
                    transforms.ToTensor(),     # 이미지를 텐서로 변환
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),     # 이미지 정규화 수행
                    transforms.Resize((224, 224))     # 이미지 크기 고정
                  ])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break

class RegressionNN(nn.Module):
    def __init__(self, dropout_rate=0.5):
        super(RegressionNN, self).__init__()
        # Use a pre-trained VGG16 as a feature extractor
        self.vgg = models.vgg16(pretrained=True)

        # Modify the last fully connected layer for regression (1 output neuron for age prediction)
        # Add dropout and batch normalization to the fully connected layer
        in_features = self.vgg.classifier[6].in_features
        self.vgg.classifier[6] = nn.Sequential(
            nn.Dropout(dropout_rate),
            nn.Linear(in_features, 256),  # You can adjust the number of neurons in the new layer
            nn.BatchNorm1d(256),           # Batch normalization
            nn.ReLU(inplace=True),         # Activation function
            nn.Dropout(dropout_rate),
            nn.Linear(256, 1),
        )

    def forward(self, x):
        return self.vgg(x)

# Instantiate the regression model
regression_model = RegressionNN(dropout_rate=0.5).to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# age_loss = nn.MSELoss()
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.0001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 200  # You can adjust the number of epochs

args = {
    "learning_rate": 0.0001,
    "batch_size": 32,
    "epochs" : num_epochs
}
wandb.config.update(args)

for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))



    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader)

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")

    wandb.log({"Train loss" : total_loss / len(train_loader),
               "Validation loss" : validation_average_mse})


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %%
# %cd new_cropped_faces

# %%
# %cd new_cropped_faces

# %%
# !ls -l | grep ^- | wc -l

# %% [markdown]
# ## MIVOLO 모델 적용

# %%
import os
from torch.utils.data import Dataset
import pandas as pd
import torch
import torchvision.transforms as transforms
import cv2
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import torch.nn as nn
from torchvision import models
import math
import random

import torch.nn as nn
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

import wandb
wandb.init(project='UTKFace regression', name='Improved_RegressionNN')
wandb.run.save()

# Configure device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# CustomDataset for UTKFace
class CustomDataset(Dataset):
    def __init__(self, root='drive/MyDrive/UTKFace/data/part1', split='train', transform=None):
        self.transform = transform
        self.root = root
        self.images = []

        for filename in os.listdir(root):
            if filename.endswith('.jpg'):
                self.images.append(filename)

        # Split data into train, validation, test sets (0.7 : 0.15 : 0.15)
        train_data, test_data = train_test_split(self.images, test_size=0.2, random_state=42)
        val_data, test_data = train_test_split(test_data, test_size=0.5, random_state=42)

        # 각 age에 대한 데이터 개수 파악
        age_counts = {}
        for filename in self.images:
            age = int(filename.split('_')[0])
            age_counts[age] = age_counts.get(age, 0) + 1

        # total : 24101
        if split == 'train':
            self.images = train_data    # 16871
        elif split == 'val':
            self.images = val_data    # 3615
        elif split == 'test':
            self.images = test_data   # 3616

        # 각 age에 대한 데이터 개수의 역수를 계산하여 확률로 사용
        total_data = len(self.images)
        self.probabilities = [1 / age_counts[int(filename.split('_')[0])] for filename in self.images]
        self.probabilities = [prob / sum(self.probabilities) for prob in self.probabilities]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        labels = []

        # 확률에 따라 데이터 샘플링
        selected_index = random.choices(range(len(self.images)), weights=self.probabilities)[0]

        # Read images
        img_path = os.path.join(self.root, self.images[selected_index])

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images = self.transform(img)

        # Extract labels from the filename
        parts = self.images[selected_index].split('_')
        age, gender, race, _ = parts
        age = int(age)
        gender = int(gender)
        race = int(race)
        labels = torch.tensor([age, gender, race], dtype=torch.float32)
        return images, labels

# Data augmentation and normalization for training
image_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    transforms.Resize((224, 224))
])

train_set = CustomDataset(split='train', transform=image_transform)
val_set = CustomDataset(split='val', transform=image_transform)
test_set = CustomDataset(split='test', transform=image_transform)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

for x, y in train_loader:
    print(x.shape)    # images
    print(y.shape)    # label
    break


# Improved Regression Model using EfficientNet as feature extractor
class ImprovedRegressionNN(nn.Module):
    def __init__(self):
        super(ImprovedRegressionNN, self).__init__()
        # Use a pre-trained EfficientNet as a feature extractor
        self.efficientnet = models.efficientnet_b0(pretrained=True)
        num_ftrs = self.efficientnet.classifier[1].in_features

        # Replace the classifier with a new regression head
        self.efficientnet.classifier = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(num_ftrs, 1)
        )

    def forward(self, x):
        return self.efficientnet(x)

# Instantiate the improved regression model
regression_model = ImprovedRegressionNN().to(DEVICE)
# Loss function for regression (Mean Squared Error) 회
# Optimizer
optimizer = torch.optim.Adam(regression_model.parameters(), lr=0.001)

def evaluate(model, test_loader):
    # Evaluation loop for regression
    model.to(DEVICE)
    model.eval()
    total_mae = 0.0
    age_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            # Extract age labels (index 0 in the label tensor)
            age_labels = y[:, 0].view(-1, 1)

            # Move data to the device
            X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

            # Forward pass
            predictions = regression_model(X)

            # age_acc += (predictions.round() == age_labels).sum().item()

            mae = nn.L1Loss()(predictions, age_labels)
            total_mae += mae.item()

    # age_acc = age_acc / len(test_loader)
    # print(f"Age accuracy: {age_acc*100}%")

    return total_mae, total_mae / len(test_loader)

# Training loop for regression
num_epochs = 100  # You can adjust the number of epochs

args = {
    "learning_rate": 0.0001,
    "batch_size": 32,
    "epochs" : num_epochs
}
wandb.config.update(args)

for epoch in range(num_epochs):
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)    # 진행 상황을 시각적으로 표시하는 라이브러리
    total_loss = 0.0

    for _, (X, y) in loop:
        # Extract age labels (index 0 in the label tensor)
        age_labels = y[:, 0].view(-1, 1)

        # Move data to the device
        X, age_labels = X.to(DEVICE), age_labels.to(DEVICE)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        predictions = regression_model(X)

        # Compute the loss
        loss = nn.L1Loss()(predictions, age_labels)

        # Backward pass
        loss.backward()

        # Update weights
        optimizer.step()

        # Update the total loss for this epoch
        total_loss += loss.item()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch+1}/{num_epochs}]")
        loop.set_postfix(loss=total_loss / len(train_loader))


    # Validation
    validation_total_mse, validation_average_mse = evaluate(regression_model, val_loader )

    # Print validation results
    print(f"Validation - Epoch [{epoch+1}/{num_epochs}], Average Mean Absolute Error: {validation_average_mse}")

    wandb.log({"Train loss" : total_loss / len(train_loader),
               "Validation loss" : validation_average_mse})


# Evaluate the model on the test set
total_mse, average_mse = evaluate(regression_model, test_loader)

# Calculate the average Mean Squared Error on the test set
print(f"Average Mean Absolute Error on the test set: {average_mse}")

# %%
# %cd /content/drive/MyDrive/MiVOLO
# Out:
# /content/drive/MyDrive/MiVOLO

# %%
# !ls

# %%
# !pip install -r requirements.txt
# !pip install .
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (0.20.3)
# Collecting ultralytics==8.0.124 (from -r requirements.txt (line 2))
#   Downloading ultralytics-8.0.124-py3-none-any.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 9.5 MB/s eta 0:00:00
# Collecting timm==0.8.13.dev0 (from -r requirements.txt (line 3))
#   Downloading timm-0.8.13.dev0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 51.7 MB/s eta 0:00:00
# Collecting yt_dlp (from -r requirements.txt (line 4))
#   Downloading yt_dlp-2023.12.30-py2.py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 85.6 MB/s eta 0:00:00
# Collecting lapx>=0.5.2 (from -r requirements.txt (line 5))
#   Downloading lapx-0.5.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (1.11.4)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (4.66.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (0.13.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.8.13.dev0->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 1)) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 1)) (23.2)
# Collecting mutagen (from yt_dlp->-r requirements.txt (line 4))
#   Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 26.7 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt_dlp->-r requirements.txt (line 4))
#   Downloading pycryptodomex-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt_dlp->-r requirements.txt (line 4)) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt_dlp->-r requirements.txt (line 4)) (2.0.7)
# Collecting websockets>=12.0 (from yt_dlp->-r requirements.txt (line 4))
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.3 MB/s eta 0:00:00
# Collecting brotli (from yt_dlp->-r requirements.txt (line 4))
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.29.32 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2->-r requirements.txt (line 5)) (3.0.8)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2->-r requirements.txt (line 5)) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.0.124->-r requirements.txt (line 2)) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.124->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->ultralytics==8.0.124->-r requirements.txt (line 2)) (1.3.0)
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, lapx, yt_dlp, ultralytics, timm
# Successfully installed brotli-1.1.0 lapx-0.5.5 mutagen-1.47.0 pycryptodomex-3.20.0 timm-0.8.13.dev0 ultralytics-8.0.124 websockets-12.0 yt_dlp-2023.12.30
# Processing /content/drive/MyDrive/MiVOLO
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from mivolo==0.5.2.dev0) (0.20.3)
# Requirement already satisfied: ultralytics==8.0.124 in /usr/local/lib/python3.10/dist-packages (from mivolo==0.5.2.dev0) (8.0.124)
# Requirement already satisfied: timm==0.8.13.dev0 in /usr/local/lib/python3.10/dist-packages (from mivolo==0.5.2.dev0) (0.8.13.dev0)
# Requirement already satisfied: yt_dlp in /usr/local/lib/python3.10/dist-packages (from mivolo==0.5.2.dev0) (2023.12.30)
# Requirement already satisfied: lapx>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from mivolo==0.5.2.dev0) (0.5.5)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm==0.8.13.dev0->mivolo==0.5.2.dev0) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.8.13.dev0->mivolo==0.5.2.dev0) (0.16.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.8.13.dev0->mivolo==0.5.2.dev0) (6.0.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.8.13.dev0->mivolo==0.5.2.dev0) (0.4.2)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (9.4.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (1.11.4)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (4.66.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (0.13.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics==8.0.124->mivolo==0.5.2.dev0) (5.9.5)
# Requirement already satisfied: Cython>=0.29.32 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2->mivolo==0.5.2.dev0) (3.0.8)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lapx>=0.5.2->mivolo==0.5.2.dev0) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->mivolo==0.5.2.dev0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->mivolo==0.5.2.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->mivolo==0.5.2.dev0) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->mivolo==0.5.2.dev0) (23.2)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (3.20.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (2.0.7)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (12.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt_dlp->mivolo==0.5.2.dev0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics==8.0.124->mivolo==0.5.2.dev0) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.124->mivolo==0.5.2.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics==8.0.124->mivolo==0.5.2.dev0) (3.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics==8.0.124->mivolo==0.5.2.dev0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm==0.8.13.dev0->mivolo==0.5.2.dev0) (1.3.0)
# Building wheels for collected packages: mivolo
#   Building wheel for mivolo (setup.py) ... done
#   Created wheel for mivolo: filename=mivolo-0.5.2.dev0-py3-none-any.whl size=37572 sha256=74e46b1fe885b2f25f7e55375102a0578018dbb19637b0e3aacb4ef093596701
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vy7bktzx/wheels/8d/c8/7c/e249604ce5e682ec8ea5260845165d7ef1353a1b47b451eef1
# Successfully built mivolo
# Installing collected packages: mivolo
# Successfully installed mivolo-0.5.2.dev0

# %%
# !python3 demo.py \
  --input "jennifer_lawrence.jpg" \
  --output "output" \
  --detector-weights "models/yolov8x_person_face.pt" \
  --checkpoint "models/model_imdb_cross_person_4.22_99.46.pth" \
  --device "cuda:0" \
  --with-persons \
  --draw
# Out:
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients
# Model meta:
# min_age: 1, max_age: 95, avg_age: 48.0, num_classes: 3, in_chans: 6, with_persons_model: True, disable_faces: False, use_persons: True, only_age: False, num_classes_gender: 2, input_size: 224, use_person_crops: True, use_face_crops: True
# Loaded state_dict from checkpoint 'models/model_imdb_cross_person_4.22_99.46.pth'
# Model mivolo_d1_224 created, param count: 27432414
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.96
# 	crop_mode: center
# 2024-02-13 14:34:39.157181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-13 14:34:39.157249: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-13 14:34:39.158625: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# 0: 384x640 1 person, 1 face, 641.4ms
# Speed: 4.2ms preprocess, 641.4ms inference, 554.4ms postprocess per image at shape (1, 3, 384, 640)
# faces_input: torch.Size([1, 3, 224, 224]), person_input: torch.Size([1, 3, 224, 224])
# 	age: 36.33
# 	gender: female [99%]
# Saved result to output/out_jennifer_lawrence.jpg

# %%
# !python3 eval_pretrained.py \
  --dataset_images /data/face_images/ \
  --dataset_annotations /data/face_images/ \
  --dataset_name utk \
  --split valid \
  --batch-size 512 \
  --checkpoint models/model_age_utk_4.23.pth \
  --half \
  --with-persons \
  --device "cuda:0"
# Out:
# Model meta:
# min_age: 21, max_age: 60, avg_age: 40.5, num_classes: 1, in_chans: 3, with_persons_model: False, disable_faces: False, use_persons: False, only_age: True, num_classes_gender: 2, input_size: 224, use_person_crops: False, use_face_crops: True
# Loaded state_dict from checkpoint 'models/model_age_utk_4.23.pth'
# Model mivolo_d1_224 created, param count: 25862810
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.485, 0.456, 0.406)
# 	std: (0.229, 0.224, 0.225)
# 	crop_pct: 0.96
# 	crop_mode: center
# csvs []
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MiVOLO/eval_pretrained.py", line 232, in <module>
#     main()
#   File "/content/drive/MyDrive/MiVOLO/eval_pretrained.py", line 205, in main
#     results = validate(args)
#   File "/content/drive/MyDrive/MiVOLO/eval_pretrained.py", line 139, in validate
#     dataset, loader = build_data(
#   File "/content/drive/MyDrive/MiVOLO/mivolo/data/dataset/__init__.py", line 33, in build
#     dataset: torch.utils.data.Dataset = dataset_class(
#   File "/content/drive/MyDrive/MiVOLO/mivolo/data/dataset/age_gender_dataset.py", line 34, in __init__
#     reader = ReaderAgeGender(
#   File "/content/drive/MyDrive/MiVOLO/mivolo/data/dataset/reader_age_gender.py", line 74, in __init__
#     self._read_annotations(images_path, annotations_path)
#   File "/content/drive/MyDrive/MiVOLO/mivolo/data/dataset/reader_age_gender.py", line 107, in _read_annotations
#     raise ValueError("Annotations are empty!")
# ValueError: Annotations are empty!

# %%
# %cd drive/MyDrive/MiVOLO/
# Out:
# /content/drive/MyDrive/MiVOLO

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd ../
# Out:
# /content/drive/MyDrive/MiVOLO

# %%
from typing import Tuple
import os

IMAGES_EXT: Tuple = (".jpeg", ".jpg", ".png", ".webp", ".bmp", ".gif")

def get_all_files(path: str, extensions: Tuple = IMAGES_EXT):
    files_all = []
    for root, subFolders, files in os.walk(path):
        print(root, subFolders, files)
        for name in files:
            # linux tricks with .directory that still is file
            if "directory" not in name and sum([ext.lower() in name.lower() for ext in extensions]) > 0:
                files_all.append(os.path.join(root, name))
    return files_all

csvs_path = "data/"
csvs = get_all_files(csvs_path, [".csv"])
print("csvs", csvs)
# Out:
# data/ ['face_images', '.ipynb_checkpoints'] ['predefined_face_train.csv']
# data/face_images ['part2', 'part3', 'part1', '.ipynb_checkpoints'] ['part1.tar.gz', 'part2.tar.gz', 'part3.tar.gz']
# data/face_images/part2 [] ['32_1_1_20170116012209350.jpg', '32_1_1_20170116023841155.jpg', '32_1_1_20170116021140504.jpg', '32_1_1_20170116012153835.jpg', '32_1_1_20170116021012241.jpg', '32_1_1_20170116160935586.jpg', '32_1_1_20170116153759560.jpg', '32_1_1_20170116154724484.jpg', '32_1_1_20170116161336538.jpg', '32_1_1_20170116030150291.jpg', '32_1_1_20170116153011586.jpg', '32_1_1_20170116192527624.jpg', '32_1_1_20170116170930529.jpg', '32_1_1_20170116164948959.jpg', '32_1_1_20170116173307655.jpg', '32_1_1_20170116164417371.jpg', '32_1_1_20170116175409630.jpg', '32_1_1_20170116174204651.jpg', '32_1_1_20170116224203659.jpg', '32_1_1_20170116234627342.jpg', '32_1_1_20170116222946705.jpg', '32_1_1_20170116223034191.jpg', '32_1_1_20170117140852897.jpg', '32_1_1_20170116232547353.jpg', '32_1_1_20170117140927443.jpg', '32_1_1_20170117140929969.jpg', '32_1_1_20170117194640746.jpg', '32_1_1_20170117183639941.jpg', '32_1_3_20170116153431215.jpg', '32_1_1_20170117140855418.jpg', '32_1_1_20170117140943466.jpg', '33_1_1_20170115234946456.jpg', '33_0_1_20170117190145954.jpg', '32_1_3_20170117184329913.jpg', '33_1_0_20170117134148014.jpg', '33_1_1_20170116024027298.jpg', '32_1_3_20170116170836443.jpg', '33_0_0_20170117164401283.jpg', '33_1_1_20170116210318759.jpg', '33_1_1_20170116233604958.jpg', '33_1_1_20170117014021084.jpg', '34_0_0_20170116192050166.jpg', '34_0_0_20170116182356566.jpg', '34_0_0_20170117103412719.jpg', '34_0_0_20